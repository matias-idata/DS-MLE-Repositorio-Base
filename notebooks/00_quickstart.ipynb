# %% [markdown]
# # Quickstart Notebook\nEste notebook muestra cómo usar el repo base sin meter lógica productiva aquí.\nLa lógica vive en `src/` y se ejecuta vía `scripts/` y `configs/`.\n

# %%
from pathlib import Path\nfrom project_name.config import load_yaml\nfrom project_name.data.io import read_csv\n\ncfg = load_yaml('configs/demo/train.yaml')\ndf = read_csv(cfg['data']['raw_path'])\ndf.head()\n
